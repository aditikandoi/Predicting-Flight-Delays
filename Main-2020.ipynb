# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns
import datetime
import pytz
from scipy import stats
from sklearn import linear_model, metrics, ensemble, model_selection,preprocessing

#Settings
pd.set_option("display.max_columns", None)

# %%
# %pwd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./MyDrive/
# Out:
# [Errno 2] No such file or directory: './MyDrive/'
# /root

# %%
# Reading airline codes and names into a dictionary
airlines_names = pd.read_csv('Yearly_Data/airlines.csv')
abbr_companies = airlines_names.set_index('IATA_CODE')['AIRLINE'].to_dict()
abbr_companies
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4ca88fdd6492> in <module>()
#       1 # Reading airline codes and names into a dictionary
# ----> 2 airlines_names = pd.read_csv('Yearly_Data/airlines.csv')
#       3 abbr_companies = airlines_names.set_index('IATA_CODE')['AIRLINE'].to_dict()
#       4 abbr_companies
#
# ...

# %%
#Read train and store csv, join them into single dataframe and print head
df_2015_1 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING.csv', low_memory=False)
df_2015_2 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 2.csv', low_memory=False)
df_2015_3 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 3.csv', low_memory=False)
df_2015_4 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 4.csv',  low_memory=False)
df_2015_5 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 5.csv',  low_memory=False)
df_2015_6 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 6.csv', low_memory=False)
df_2015_7 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 7.csv', low_memory=False)
df_2015_8 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 8.csv', low_memory=False)
df_2015_9 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 9.csv',  low_memory=False)
df_2015_10 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 10.csv', low_memory=False)
df_2015_11 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 11.csv',  low_memory=False)
df_2015_12 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 12.csv', low_memory=False)
result_2015 = pd.concat([df_2015_1,df_2015_2,df_2015_3,df_2015_4,df_2015_5,df_2015_6,df_2015_7,df_2015_8,df_2015_9,df_2015_10,df_2015_11,df_2015_12])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/47/4f7jm34s71qf5mqcq97k7ct00000gn/T/ipykernel_60907/933642510.py in <module>
#       1 #Read train and store csv, join them into single dataframe and print head
#       2 df_2015_1 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING.csv', low_memory=False)
# ----> 3 df_2015_2 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 2.csv', low_memory=False)
#       4 df_2015_3 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 3.csv', low_memory=False)
#       5 df_2015_4 = pd.read_csv('Yearly_Data/2015/440927628_T_ONTIME_REPORTING 4.csv',  low_memory=False)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
# ...

# %%
#Read train and store csv, join them into single dataframe and print head
df_2016_1 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING.csv', low_memory=False)
df_2016_2 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 2.csv', low_memory=False)
df_2016_3 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 3.csv', low_memory=False)
df_2016_4 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 4.csv',  low_memory=False)
df_2016_5 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 5.csv',  low_memory=False)
df_2016_6 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 6.csv', low_memory=False)
df_2016_7 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 7.csv', low_memory=False)
df_2016_8 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 8.csv', low_memory=False)
df_2016_9 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 9.csv',  low_memory=False)
df_2016_10 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 10.csv', low_memory=False)
df_2016_11 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 11.csv',  low_memory=False)
df_2016_12 = pd.read_csv('Yearly_Data/2016/440927628_T_ONTIME_REPORTING 12.csv', low_memory=False)
result_2016 = pd.concat([df_2016_1,df_2016_2,df_2016_3,df_2016_4,df_2016_5,df_2016_6,df_2016_7,df_2016_8,df_2016_9,df_2016_10,df_2016_11,df_2016_12])

# %%
#Read train and store csv, join them into single dataframe and print head
df_2017_1 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING.csv', low_memory=False)
df_2017_2 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 2.csv', low_memory=False)
df_2017_3 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 3.csv', low_memory=False)
df_2017_4 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 4.csv',  low_memory=False)
df_2017_5 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 5.csv',  low_memory=False)
df_2017_6 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 6.csv', low_memory=False)
df_2017_7 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 7.csv', low_memory=False)
df_2017_8 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 8.csv', low_memory=False)
df_2017_9 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 9.csv',  low_memory=False)
df_2017_10 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 10.csv', low_memory=False)
df_2017_11 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 11.csv',  low_memory=False)
df_2017_12 = pd.read_csv('Yearly_Data/2017/440927628_T_ONTIME_REPORTING 12.csv', low_memory=False)
result_2017 = pd.concat([df_2017_1,df_2017_2,df_2017_3,df_2017_4,df_2017_5,df_2017_6,df_2017_7,df_2017_8,df_2017_9,df_2017_10,df_2017_11,df_2017_12])

# %%
#Read train and store csv, join them into single dataframe and print head
df_2018_1 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING.csv', low_memory=False)
df_2018_2 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 2.csv', low_memory=False)
df_2018_3 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 3.csv', low_memory=False)
df_2018_4 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 4.csv',  low_memory=False)
df_2018_5 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 5.csv',  low_memory=False)
df_2018_6 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 6.csv', low_memory=False)
df_2018_7 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 7.csv', low_memory=False)
df_2018_8 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 8.csv', low_memory=False)
df_2018_9 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 9.csv',  low_memory=False)
df_2018_10 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 10.csv', low_memory=False)
df_2018_11 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 11.csv',  low_memory=False)
df_2018_12 = pd.read_csv('Yearly_Data/2018/440927628_T_ONTIME_REPORTING 12.csv', low_memory=False)
result_2018 = pd.concat([df_2018_1,df_2018_2,df_2018_3,df_2018_4,df_2018_5,df_2018_6,df_2018_7,df_2018_8,df_2018_9,df_2018_10,df_2018_11,df_2018_12])

# %%
#Read train and store csv, join them into single dataframe and print head
df_2019_1 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING.csv', low_memory=False)
df_2019_2 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING1.csv', low_memory=False)
df_2019_3 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING2.csv', low_memory=False)
df_2019_4 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING3.csv',  low_memory=False)
df_2019_5 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING4.csv',  low_memory=False)
df_2019_6 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING5.csv', low_memory=False)
df_2019_7 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING6.csv', low_memory=False)
df_2019_8 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING7.csv', low_memory=False)
df_2019_9 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING8.csv',  low_memory=False)
df_2019_10 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING9.csv', low_memory=False)
df_2019_11 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING10.csv',  low_memory=False)
df_2019_12 = pd.read_csv('Yearly_Data/2019/436342248_T_ONTIME_REPORTING11.csv', low_memory=False)
result_2019 = pd.concat([df_2019_1,df_2019_2,df_2019_3,df_2019_4,df_2019_5,df_2019_6,df_2019_7,df_2019_8,df_2019_9,df_2019_10,df_2019_11,df_2019_12])

# %%
#Read train and store csv, join them into single dataframe and print head
df_2020_1 = pd.read_csv('Yearly_Data/2020/436348265_T_ONTIME_REPORTING.csv', low_memory=False)
df_2020_2 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING1.csv', low_memory=False)
df_2020_3 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING2.csv', low_memory=False)
df_2020_4 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING3.csv', low_memory=False)
df_2020_5 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING4.csv', low_memory=False)
df_2020_6 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING5.csv', low_memory=False)
df_2020_7 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING6.csv', low_memory=False)
df_2020_8 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING7.csv', low_memory=False)
df_2020_9 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING8.csv', low_memory=False)
df_2020_10 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING9.csv', low_memory=False)
df_2020_11 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING10.csv', low_memory=False)
df_2020_12 = pd.read_csv('Yearly_Data/2020/436342248_T_ONTIME_REPORTING11.csv', low_memory=False)
result_2020 = pd.concat([df_2020_1,df_2020_2,df_2020_3,df_2020_4,df_2020_5,df_2020_6,df_2020_7,df_2020_8,df_2020_9,df_2020_10,df_2020_11,df_2020_12])

# %%
# Concatinating data for 2017 and 2018, and creating a safe copy of df
df = pd.concat([result_2017,result_2018])
safe_copy = df.copy()

# %%
# Top 20 businest airports from wikipedia and filtering the dataframe
busiest_airports_iata = ["ATL", "DFW", "DEN", "ORD", "LAX", "CLT", "LAS", "PHX", "MCO", "SEA", "MIA", "IAH", "JFK", "FLL", "SFO", "EWR", "MSP", "DTW", "BOS", "PHL"]
df = df[df.DEST.isin(busiest_airports_iata) & (df.ORIGIN.isin(busiest_airports_iata))]

# %% [markdown]
# Feature cleaning

# %%
# Removing rows where arr and dep delay is NAN
df = df[(df['ARR_DELAY'].notna()) & (df['DEP_DELAY'].notna())]

# We don't need cancelled flights in our dataset
df = df[df.CANCELLED !=1]

# Converting flight date to date time
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])

# Removing unused columns
variables_to_remove = ['OP_UNIQUE_CARRIER','CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
       'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 42','CANCELLED','DIVERTED','FLIGHTS','CANCELLATION_CODE']
df = df.drop(columns=variables_to_remove)

# %%
# Function to convert 24hrs time format to HH:MM
def format_heure(chaine):
    if pd.isnull(chaine):
        return np.nan
    else:
        if chaine == 2400: chaine = 0
        chaine = "{0:04d}".format(int(chaine))
        heure = datetime.time(int(chaine[0:2]), int(chaine[2:4]))
        return heure

# Converting time to HH:MM
df['CRS_ARR_TIME'] = df['CRS_ARR_TIME'].apply(format_heure)
df['ARR_TIME'] = df['ARR_TIME'].apply(format_heure)
df['CRS_DEP_TIME'] = df['CRS_DEP_TIME'].apply(format_heure)
df['DEP_TIME'] = df['DEP_TIME'].apply(format_heure)

# %%
# Cheking the type and null values for each column
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info
# Out:
#                    YEAR QUARTER  MONTH DAY_OF_MONTH DAY_OF_WEEK  \
# column type       int64   int64  int64        int64       int64
# null values (nb)      0       0      0            0           0
#
#                          FL_DATE OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  \
# column type       datetime64[ns]                 int64     object   object
# null values (nb)               0                     0          0        0
#
#                  OP_CARRIER_FL_NUM ORIGIN_AIRPORT_ID  ORIGIN ORIGIN_CITY_NAME  \
# column type                  int64             int64  object           object
# null values (nb)                 0                 0       0                0
#
#                  ORIGIN_STATE_ABR DEST_AIRPORT_ID    DEST DEST_CITY_NAME  \
# column type                object           int64  object         object
# null values (nb)                0               0       0              0
#
#                  DEST_STATE_ABR CRS_DEP_TIME DEP_TIME DEP_DELAY DEP_DELAY_NEW  \
# ...

# %%
# Adding new column 'Total Delay' which is sum of dep delay and arr delay
df['Total_Delay'] = df.DEP_DELAY_NEW+df.ARR_DELAY_NEW

# %%
# Plotting total delay by airline
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['Total_Delay'].apply(delay_type)
df_temp = df[df["DELAY_LEVEL"] > 0]
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="OP_CARRIER", hue='DELAY_LEVEL', data=df_temp)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
#L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[0].set_text('small delay (5 < t < 45 min)')
L.get_texts()[1].set_text('large delay (t > 45 min)')
plt.show()

# %%
# From above graph we notice that some airlines have very few delayed flights. 
# Since they won't contribute much in predicting delays, therefore we remove them.
df=df[~df["OP_CARRIER"].isin(["EV","9E","OH","YX","MQ","YV"])]

# Plotting graph again for total delay
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['Total_Delay'].apply(delay_type)
df_temp = df[df["DELAY_LEVEL"] > 0]
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="OP_CARRIER", hue='DELAY_LEVEL', data=df_temp)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
#L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[0].set_text('small delay (5 < t < 45 min)')
L.get_texts()[1].set_text('large delay (t > 45 min)')
plt.show()

# %%
# Plotting departure delay by airline

delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['DEP_DELAY'].apply(delay_type)
df_temp = df[df["DELAY_LEVEL"] > 0]

#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="OP_CARRIER", hue='DELAY_LEVEL', data=df_temp)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
#L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[0].set_text('small delay (5 < t < 45 min)')
L.get_texts()[1].set_text('large delay (t > 45 min)')
plt.show()

# %%
# Plotting arr delay by airline
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['ARR_DELAY'].apply(delay_type)
df_temp = df[df["DELAY_LEVEL"] > 0]

#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="OP_CARRIER", hue='DELAY_LEVEL', data=df_temp)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
#L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[0].set_text('small delay (5 < t < 45 min)')
L.get_texts()[1].set_text('large delay (t > 45 min)')
plt.show()

# %%
sns.set(rc={'figure.figsize':(13,9)})
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap='seismic');

# %%
#Weather column headers
columns = ["key", "date", "class", "expire_time_gmt", "obs_id", "obs_name", "valid_time_gmt", "day_ind", "temp", "wx_icon", "icon_extd", "wx_phrase", "pressure_tend", "pressure_desc", "dewPt", "heat_index", "rh", "pressure", "vis", "wc", "wdir", "wdir_cardinal", "gust", "wspd", "max_temp", "min_temp", "precip_total", "precip_hrly", "snow_hrly", "uv_desc", "feels_like", "uv_index", "qualifier", "qualifier_svrty", "blunt_phrase", "terse_phrase", "clds", "water_temp", "primary_wave_period", "primary_wave_height", "primary_swell_period", "primary_swell_height", "primary_swell_direction", "secondary_swell_period", "secondary_swell_height", "secondary_swell_direction",]

# %%
# Reading weather data from csv files
path = "Weather_Data/"  # use your path
lst = []

for airport in busiest_airports_iata:
    lst.append(pd.read_csv(path + airport + ".csv", low_memory=False,names = columns))
main_df = pd.concat(lst)

# %%
# Removing header columns
main_df = main_df[main_df['key'] != 'key']

# Selecting important features, filtering df, and dropping na values
req_cols=['key','date','temp','pressure','wc','wspd', 'wx_phrase','dewPt','vis']
main_df = main_df[req_cols]
main_df = main_df.dropna()

# Removing extra character from airport code that was part of downloaded data, and rest index
main_df['key'] = main_df['key'].str.slice(start=1)
main_df.reset_index(inplace=True)
main_df=main_df.drop(columns=["index"])

# %%
main_df_preprocess = main_df.copy()

# %%
dic = {'ATL': 'America/New_York', 'DFW': 'America/Chicago', 'DEN': 'America/Denver', 'ORD': 'America/Chicago', 'LAX': 'America/Los_Angeles', 'CLT': 'America/New_York', 'LAS': 'America/Los_Angeles', 'PHX': 'America/Phoenix', 'MCO': 'America/New_York',
       'SEA': 'America/Los_Angeles', 'MIA' : 'America/New_York', 'IAH': 'America/Chicago', 'JFK': 'America/New_York', 'FLL': 'America/New_York', 'SFO': 'America/Los_Angeles', 'EWR': 'America/New_York', 'MSP': 'America/Chicago', 'DTW': 'America/Detroit',
       'BOS': 'America/New_York', 'PHL': 'America/New_York'}

# %%
main_df_preprocess.head()
# Out:
#    key                 date temp pressure  wc wspd   wx_phrase dewPt vis
# 0  ATL  2019-01-01 05:19:00   66    28.94  66    7  Light Rain    64   4
# 1  ATL  2019-01-01 05:36:00   66    28.94  66    9        Rain    63   2
# 2  ATL  2019-01-01 05:43:00   66    28.94  66    6  Light Rain    64   5
# 3  ATL  2019-01-01 05:52:00   66    28.94  66    5  Light Rain    64   5
# 4  ATL  2019-01-01 06:33:00   66    28.94  66    5      Cloudy    64   6

# %%
main_df_preprocess['date'] =  pd.to_datetime(main_df_preprocess['date'])
main_df_preprocess['date'] = main_df_preprocess.apply(lambda x: \
                                                      pytz.timezone(dic[x['key']]).localize(x['date']).astimezone(dic[x['key']]),axis=1)

# %%
main_df_preprocess['Merge_Date'] = main_df_preprocess['date'].apply(lambda x : x.replace(tzinfo=None))
main_df_preprocess['Merge_Airport'] = main_df_preprocess['key']

# %%
# Preparing flights data to merge on departure time
df['Merge_Date'] = df.apply(lambda x: pd.Timestamp(x.FL_DATE).replace(hour=x['CRS_DEP_TIME'].hour, 
                                        minute=x['CRS_DEP_TIME'].minute, second=x['CRS_DEP_TIME'].second), axis=1)
df['Merge_Airport'] = df['ORIGIN']

# %%
# Merging flights with weather on departure time
merged_df = pd.merge_asof(df.sort_values('Merge_Date'), main_df_preprocess.sort_values('Merge_Date'),
                          on = "Merge_Date", by='Merge_Airport', direction="nearest", allow_exact_matches=True)

# %%
df_dep = pd.merge_asof(df.sort_values('Merge_Date'), main_df_preprocess.sort_values('Merge_Date'),
                          on = "Merge_Date", by='Merge_Airport', direction="nearest", allow_exact_matches=True)
df['Merge_Date'] = df.apply(lambda x: pd.Timestamp(x.FL_DATE).replace(hour=x['CRS_ARR_TIME'].hour, 
                                        minute=x['CRS_ARR_TIME'].minute, second=x['CRS_ARR_TIME'].second), axis=1)
df['Merge_Airport'] = df['DEST']
df_arr = pd.merge_asof(df.sort_values('Merge_Date'), main_df_preprocess.sort_values('Merge_Date'),
                          on = "Merge_Date", by='Merge_Airport', direction="nearest", allow_exact_matches=True)

# %%
# Preparing flights data to merge on arrival time
df['Merge_Date'] = df.apply(lambda x: pd.Timestamp(x.FL_DATE).replace(hour=x['CRS_ARR_TIME'].hour, 
                                        minute=x['CRS_ARR_TIME'].minute, second=x['CRS_ARR_TIME'].second), axis=1)
df['Merge_Airport'] = df['DEST']

# %%
# Merging flights with weather on arrival time
merged_df_dest = pd.merge_asof(merged_df.sort_values('Merge_Date'), main_df_preprocess.sort_values('Merge_Date'),
                               on = "Merge_Date", by='Merge_Airport', direction="nearest", allow_exact_matches=True)
final_safe_copy = merged_df_dest.copy()

# %%
# Just a copy that can be reused if something gets messep up.
merged_df_dest = final_safe_copy

# %%
# Removing final columns which are not needed anymore
remove_final_cols = ['QUARTER', 'DAY_OF_WEEK', 'FL_DATE', 'OP_CARRIER_AIRLINE_ID', 'ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_NAME', \
                     'DEST_AIRPORT_ID', 'DEST_CITY_NAME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15', 'ARR_TIME', \
                     'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'key_x', 'date_x', \
                     'key_y', 'date_y','wx_phrase_y','wx_phrase_x','ORIGIN_STATE_ABR','DEST_STATE_ABR','Merge_Airport',\
                     'TAIL_NUM','OP_CARRIER_FL_NUM','Merge_Date']

# %%
df_eda = merged_df_dest.drop(columns = remove_final_cols)

# %%
for dataset in df_eda:
    df_eda.loc[df_eda['Total_Delay'] <= 5, 'Status'] = 'Slightly Delayed'
    df_eda.loc[df_eda['Total_Delay'] >= 5, 'Status'] = 'Moderately Delayed'
    df_eda.loc[df_eda['Total_Delay'] >= 30, 'Status'] = 'Heavily Delayed'
    df_eda.loc[df_eda['Total_Delay'] == 0, 'Status'] = 'On Time'

# %%
f,ax=plt.subplots(1,2,figsize=(25,12))
df_eda['Status'].value_counts().plot.pie(explode=[0.05,0.05,0.05, 0.05],autopct='%1.1f%%',ax=ax[0], shadow=True)
ax[0].set_title('DELAY STATUS')
ax[0].set_ylabel('')
sns.countplot('Status',order = df_eda['Status'].value_counts().index, data=df_eda,ax=ax[1])
ax[1].set_title('DELAY STATUS')
plt.show()

# %%
df_eda_2 = df[df.DEP_DELAY >= 0]

# %%
df_eda_3 = df[df.ARR_DELAY >= 0]

# %%
#f,ax=plt.subplots(1,1,figsize=(35,10))
sns.set(rc={'figure.figsize':(20,7)})
sns.barplot('ORIGIN','DEP_DELAY', data=df_eda_2, palette = 'ch:s=.25,rot=-.25').set_title('DEPARTURE DELAY BY AIRPORTS')
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.barplot('DEST','ARR_DELAY', data=df_eda_3, palette = 'flare').set_title('ARRIVAL DELAY BY AIRPORTS')
plt.show()

# %%
df_eda_4 = df_eda_4[df_eda_4.DEP_DELAY > 0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-215-a6eaee861585> in <module>
# ----> 1 df_eda_4 = df_eda_4[df_eda_4.DEP_DELAY > 0]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'DEP_DELAY'

# %%
delays_by_airline = df[df.DEP_DELAY_NEW > 0].groupby('ORIGIN').count()
flights_by_airline = df.groupby('ORIGIN').count()
percent_delay_airline = delays_by_airline/flights_by_airline
percent_delay_airline.reset_index(inplace=True)
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot('ORIGIN','DEP_DELAY_NEW', data=percent_delay_airline, order = busy_airports_dep).set_title('DEPARTURE DELAY BY BUSIEST AIRPORTS')
plt.show()

# %%
delays_by_airline = df[df.ARR_DELAY_NEW > 0].groupby('DEST').count()
flights_by_airline = df.groupby('DEST').count()
percent_delay_airline = delays_by_airline/flights_by_airline
percent_delay_airline.reset_index(inplace=True)
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot('DEST','ARR_DELAY_NEW', data=percent_delay_airline, order = busy_airports_dep).set_title('DEPARTURE DELAY BY BUSIEST AIRPORTS')
plt.show()

# %%
df_eda_4 = df_eda.groupby('ORIGIN').count()
df_eda_4 = df_eda_4['YEAR']

# %%
df_eda_4
# Out:
# ORIGIN
# ATL    177362
# BOS    115209
# CLT    103936
# DEN    143518
# DFW    141038
# DTW     98843
# EWR    107524
# FLL     77813
# IAH    100761
# JFK     93779
# LAS    123913
# LAX    181423
# MCO    111324
# MIA     72531
# MSP     96054
# ORD    166649
# PHL     91735
# PHX    113171
# SEA    111726
# SFO    133483
# Name: YEAR, dtype: int64

# %%
df_eda_4 = df_eda_4.sort_values(ascending = False)

# %%
df_eda_4
# Out:
# ORIGIN
# LAX    181423
# ATL    177362
# ORD    166649
# DEN    143518
# DFW    141038
# SFO    133483
# LAS    123913
# BOS    115209
# PHX    113171
# SEA    111726
# MCO    111324
# EWR    107524
# CLT    103936
# IAH    100761
# DTW     98843
# MSP     96054
# JFK     93779
# PHL     91735
# FLL     77813
# MIA     72531
# Name: YEAR, dtype: int64

# %%
busy_airports_dep = df_eda_4.index
busy_airports_dep
# Out:
# Index(['LAX', 'ATL', 'ORD', 'DEN', 'DFW', 'SFO', 'LAS', 'BOS', 'PHX', 'SEA',
#        'MCO', 'EWR', 'CLT', 'IAH', 'DTW', 'MSP', 'JFK', 'PHL', 'FLL', 'MIA'],
#       dtype='object', name='ORIGIN')

# %%
df_eda_5 = df.groupby('ORIGIN', as_index=False)['DEP_DELAY'].mean()
df_eda_5
# Out:
#    ORIGIN  DEP_DELAY
# 0     ATL   7.731566
# 1     BOS   8.437405
# 2     CLT   8.924415
# 3     DEN   8.829694
# 4     DFW  11.617032
# 5     DTW   7.019061
# 6     EWR  12.128725
# 7     FLL   8.386606
# 8     IAH   9.737438
# 9     JFK   8.359793
# 10    LAS   7.603165
# 11    LAX   7.019358
# 12    MCO   8.671652
# 13    MIA   9.063876
# 14    MSP   6.948446
# 15    ORD  10.923714
# 16    PHL   7.121535
# 17    PHX   6.843087
# 18    SEA   6.103584
# 19    SFO   8.563750

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot('ORIGIN','DEP_DELAY', data=df_eda_5, order = busy_airports_dep).set_title('DEPARTURE DELAY BY BUSIEST AIRPORTS')
plt.show()

# %%
df_eda_4 = df_eda.groupby('DEST').count()
df_eda_4 = df_eda_4['YEAR']

# %%
df_eda_4 = df_eda_4.sort_values(ascending = False)

# %%
df_eda_4
# Out:
# DEST
# LAX    181635
# ATL    177323
# ORD    166679
# DEN    143382
# DFW    140741
# SFO    133350
# LAS    124189
# BOS    115353
# PHX    113066
# SEA    111668
# MCO    111532
# EWR    107372
# CLT    103883
# IAH    100656
# DTW     98907
# MSP     96103
# JFK     93746
# PHL     91919
# FLL     77737
# MIA     72551
# Name: YEAR, dtype: int64

# %%
busy_airports_arr = df_eda_4.index
busy_airports_arr
# Out:
# Index(['LAX', 'ATL', 'ORD', 'DEN', 'DFW', 'SFO', 'LAS', 'BOS', 'PHX', 'SEA',
#        'MCO', 'EWR', 'CLT', 'IAH', 'DTW', 'MSP', 'JFK', 'PHL', 'FLL', 'MIA'],
#       dtype='object', name='DEST')

# %%
df_eda_5 = df.groupby('DEST', as_index=False)['ARR_DELAY'].mean()
df_eda_5
# Out:
#    DEST  ARR_DELAY
# 0   ATL  -0.333894
# 1   BOS   2.175661
# 2   CLT  -0.286486
# 3   DEN   0.920820
# 4   DFW   5.189973
# 5   DTW   0.191695
# 6   EWR   7.377342
# 7   FLL   1.677065
# 8   IAH   2.581217
# 9   JFK   0.636379
# 10  LAS   1.438638
# 11  LAX  -1.069117
# 12  MCO   0.934243
# 13  MIA   0.270127
# 14  MSP   0.148091
# 15  ORD   2.927429
# 16  PHL   0.418967
# 17  PHX   1.273318
# 18  SEA  -0.744546
# 19  SFO   3.288106

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot('DEST','ARR_DELAY', data=df_eda_5, order = busy_airports_arr).set_title('ARRIVAL DELAY BY BUSIEST AIRPORTS')
plt.show()

# %%
df_total_monthly = df.groupby(["OP_CARRIER","YEAR","MONTH"]).count()['ORIGIN'].reset_index()
df_total_monthly = df_total_monthly.rename(columns={"ORIGIN": "TOTAL"})
df_total_monthly_delayed = df[df.ARR_DELAY_NEW > 0].groupby(["OP_CARRIER","YEAR","MONTH"]).count()['ORIGIN'].reset_index()
df_total_monthly_delayed = df_total_monthly_delayed.rename(columns={"ORIGIN": "DELAYED"})
temp = pd.merge(df_total_monthly , df_total_monthly_delayed, how='inner')
temp['Percent_Delayed'] = temp.DELAYED/temp.TOTAL
temp['Year_Month'] = temp.YEAR.astype(str) + temp.MONTH.astype(str)
sns.set(rc={'figure.figsize':(19,9)})
ax = sns.lineplot(x = "Year_Month", y="Percent_Delayed", hue="OP_CARRIER", data=temp)
ax.set(title='monthly % of flights delayed by airline')
#ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.xlabel("Year and Month")
plt.tight_layout()

# %%
temp = df[df.Total_Delay > 0]
sns.scatterplot(x="DISTANCE", y="Total_Delay", data=temp).set_title('Sales against customers by store type')
# Out:
# Text(0.5, 1.0, 'Sales against customers by store type')

# %%
year_month = []
for i in range(len(temp)):
    value = '(' + str(temp.YEAR[i]) + ' ,' + str(temp.MONTH)[i] + ')'
    year_month.append(value)
temp['Year_Month'] = year_month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/47/4f7jm34s71qf5mqcq97k7ct00000gn/T/ipykernel_60922/481604760.py in <module>
#       1 year_month = []
# ----> 2 for i in range(len(temp)):
#       3     value = '(' + str(temp.YEAR[i]) + ' ,' + str(temp.MONTH)[i] + ')'
#       4     year_month.append(value)
#       5 temp['Year_Month'] = year_month
#
# NameError: name 'temp' is not defined

# %%
#% monthly percentage delayed by carrier

# Sum up sales by week
df_temp = (df.groupby(["OP_CARRIER","YEAR","MONTH"]).count().reset_index())


delays_by_airline = df[df.ARR_DELAY_NEW > 0].groupby('DEST').count()
flights_by_airline = df.groupby('DEST').count()
percent_delay_airline = delays_by_airline/flights_by_airline
percent_delay_airline.reset_index(inplace=True)
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot('DEST','ARR_DELAY_NEW', data=percent_delay_airline, order = busy_airports_dep).set_title('DEPARTURE DELAY BY BUSIEST AIRPORTS')
plt.show()

# Plot results
sns.set(rc={'figure.figsize':(19,7)})
ax = sns.pointplot(x = "week_no", y="Sales", hue="Store", data=df_bottom_5_store_totalsales_byweek)
ax.set(title='Weekly Sales for five lowest selling stores')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.xlabel("Week No")
plt.tight_layout()

# %%
temp2
# Out:
#    OP_CARRIER  YEAR  TOTAL_FLIGHTS
# 0          9E  2018          18394
# 1          AA  2017         400943
# 2          AA  2018         398344
# 3          AS  2017          45890
# 4          AS  2018          76627
# 5          B6  2017          85538
# 6          B6  2018          90639
# 7          DL  2017         285039
# 8          DL  2018         299065
# 9          EV  2017           2146
# 10         EV  2018            430
# 11         F9  2017          33383
# 12         F9  2018          26445
# 13         MQ  2018           5520
# 14         NK  2017          72922
# 15         NK  2018          78299
# 16         OH  2018           3893
# 17         OO  2017          49823
# 18         OO  2018          40868
# 19         UA  2017         269048
# 20         UA  2018         272920
# 21         VX  2017          45579
# 22         VX  2018          10691
# 23         WN  2017         118523
# 24         WN  2018         117802
# 25         YV  2018          15784
# ...

# %%
all_carriers = merged_df_dest['OP_CARRIER'].unique()
all_carriers
# Out:
# array(['AA', 'NK', 'UA', 'DL', 'AS', 'F9', 'B6', 'WN', 'OO', 'VX', 'EV',
#        'YX', '9E', 'YV', 'OH', 'MQ'], dtype=object)

# %%
carrier = []
merged_df_dest.OP_CARRIER.unique()
for i in range(16):
    if temp2.Airline[i] == i:
        carrier.append(abbr_companies[all_carriers[i]])
carrier
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/47/4f7jm34s71qf5mqcq97k7ct00000gn/T/ipykernel_59555/2173767947.py in <module>
#       2 merged_df_dest.OP_CARRIER.unique()
#       3 for i in range(16):
# ----> 4     if temp2.Airline[i] == i:
#       5         carrier.append(abbr_companies[all_carriers[i]])
#       6 carrier
#
# NameError: name 'temp2' is not defined

# %%
final_merged_df = merged_df_dest.drop(columns = remove_final_cols)
final_merged_df
# Out:
#          YEAR  MONTH  DAY_OF_MONTH OP_CARRIER ORIGIN DEST CRS_DEP_TIME  \
# 0        2017      1             1         AA    SFO  CLT     00:15:00
# 1        2017      1             1         AA    SEA  CLT     00:15:00
# 2        2017      1             1         NK    MSP  FLL     00:20:00
# 3        2017      1             1         UA    LAX  ORD     00:21:00
# 4        2017      1             1         DL    SEA  MSP     00:30:00
# ...       ...    ...           ...        ...    ...  ...          ...
# 2818383  2018     12            31         B6    DEN  JFK     23:59:00
# 2818384  2018     12            31         B6    SEA  BOS     23:59:00
# 2818385  2018     12            31         B6    SFO  FLL     23:59:00
# 2818386  2018     12            31         UA    SFO  PHL     23:59:00
# 2818387  2018     12            31         DL    LAS  ATL     23:59:00
#
#         CRS_ARR_TIME  DISTANCE  Total_Delay  DELAY_LEVEL temp_x pressure_x  \
# ...

# %%
final_merged_df['temp_x'] = final_merged_df['temp_x'].astype(float)
final_merged_df['pressure_x'] = final_merged_df['pressure_x'].astype(float)
final_merged_df['wc_x'] = final_merged_df['wc_x'].astype(float)
final_merged_df['wspd_x'] = final_merged_df['wspd_x'].astype(float)
final_merged_df['dewPt_x'] = final_merged_df['dewPt_x'].astype(float)
final_merged_df['vis_x'] = final_merged_df['vis_x'].astype(float)
final_merged_df['temp_y'] = final_merged_df['temp_y'].astype(float)
final_merged_df['pressure_y'] = final_merged_df['pressure_y'].astype(float)
final_merged_df['wc_y'] = final_merged_df['wc_y'].astype(float)
final_merged_df['wspd_y'] = final_merged_df['wspd_y'].astype(float)
final_merged_df['dewPt_y'] = final_merged_df['dewPt_y'].astype(float)
final_merged_df['vis_y'] = final_merged_df['vis_y'].astype(float)

# %%
final_merged_df.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#                 YEAR          MONTH   DAY_OF_MONTH       DISTANCE  \
# count  2818388.00000  2818388.00000  2818388.00000  2818388.00000
# mean      2017.50089        6.54967       15.78317     1156.18518
# std          0.50000        3.39297        8.78068      674.48011
# min       2017.00000        1.00000        1.00000       94.00000
# 25%       2017.00000        4.00000        8.00000      650.00000
# 50%       2018.00000        7.00000       16.00000      967.00000
# 75%       2018.00000        9.00000       23.00000     1597.00000
# max       2018.00000       12.00000       31.00000     2724.00000
#
#          Total_Delay    DELAY_LEVEL         temp_x     pressure_x  \
# count  2818388.00000  2818388.00000  2818388.00000  2818388.00000
# mean        28.18748        0.38726       45.05475       29.20500
# std         84.30442        0.64876       18.73631        1.28946
# min          0.00000        0.00000       -2.00000       24.71000
# ...

# %%
final_merged_df[final_merged_df.Total_Delay > 1440]
# Out:
#          YEAR  MONTH  DAY_OF_MONTH OP_CARRIER ORIGIN DEST CRS_DEP_TIME  \
# 3176     2017      1             1         NK    FLL  LAS     20:30:00
# 3577     2017      1             2         NK    LAS  DFW     00:59:00
# 3971     2017      1             2         AA    MSP  DFW     07:00:00
# 7136     2017      1             2         UA    MIA  EWR     20:44:00
# 11568    2017      1             4         UA    SEA  EWR     06:21:00
# ...       ...    ...           ...        ...    ...  ...          ...
# 2806349  2018     12            28         AA    PHL  DFW     18:25:00
# 2813166  2018     12            30         OO    IAH  MSP     14:19:00
# 2817711  2018     12            31         OO    DEN  DFW     17:45:00
# 2817771  2018     12            31         OO    MSP  IAH     18:01:00
# 2817991  2018     12            31         DL    MSP  EWR     19:30:00
#
#         CRS_ARR_TIME  DISTANCE  Total_Delay  DELAY_LEVEL  temp_x  pressure_x  \
# ...

# %%
final_merged_df
# Out:
#          YEAR  MONTH  DAY_OF_MONTH OP_CARRIER ORIGIN DEST CRS_DEP_TIME  \
# 0        2017      1             1         DL    ATL  MIA     22:05:00
# 1        2017      1             1         UA    ORD  IAH     21:20:00
# 2        2017      1             1         NK    EWR  FLL     21:00:00
# 3        2017      1             1         AA    CLT  EWR     22:15:00
# 4        2017      1             1         UA    LAX  ORD     18:01:00
# ...       ...    ...           ...        ...    ...  ...          ...
# 2894519  2018     12            31         NK    LAS  DFW     19:26:00
# 2894520  2018     12            31         AA    PHX  BOS     17:18:00
# 2894521  2018     12            31         B6    BOS  JFK     22:48:00
# 2894522  2018     12            31         B6    EWR  FLL     21:00:00
# 2894523  2018     12            31         NK    LAX  IAH     18:45:00
#
#         CRS_ARR_TIME  DISTANCE  Total_Delay  temp_x  pressure_x  wc_x  wspd_x  \
# ...

# %%
final_merged_df['crs_dep_hour'] = final_merged_df.apply(lambda x: x['CRS_DEP_TIME'].hour,axis=1)
final_merged_df['crs_dep_minute'] = final_merged_df.apply(lambda x: x['CRS_DEP_TIME'].minute,axis=1)

# %%
final_merged_df['crs_arr_hour'] = final_merged_df.apply(lambda x: x['CRS_ARR_TIME'].hour,axis=1)
final_merged_df['crs_arr_minute'] = final_merged_df.apply(lambda x: x['CRS_ARR_TIME'].minute,axis=1)

# %%
final_merged_df.drop(columns=['CRS_DEP_TIME','CRS_ARR_TIME'], inplace=True)

# %%
def column_types(df):
    category_cols = []
    for col in df.columns:
        if df[col].dtype.name == 'object':
            category_cols.append(col)
    return category_cols

# %%
category_cols = column_types(final_merged_df)
category_cols
# Out:
# ['OP_CARRIER', 'ORIGIN', 'DEST']

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(final_merged_df['OP_CARRIER'].astype(str))
final_merged_df['OP_CARRIER'] = le1.transform(final_merged_df['OP_CARRIER'])

le2 = preprocessing.LabelEncoder()
le2.fit(final_merged_df['ORIGIN'].astype(str))
final_merged_df['ORIGIN'] = le2.transform(final_merged_df['ORIGIN'])

le3 = preprocessing.LabelEncoder()
le3.fit(final_merged_df['DEST'].astype(str))
final_merged_df['DEST'] = le3.transform(final_merged_df['DEST'])

# %%
final_merged_df
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  OP_CARRIER  ORIGIN  DEST  DISTANCE  \
# 0        2017      1             1           0      19     2    2296.0
# 1        2017      1             1           0      18     2    2279.0
# 2        2017      1             1           5      14     7    1487.0
# 3        2017      1             1           7      11    15    1744.0
# 4        2017      1             1           3      18    14    1399.0
# ...       ...    ...           ...         ...     ...   ...       ...
# 2818383  2018     12            31           2       3     9    1626.0
# 2818384  2018     12            31           2      18     1    2496.0
# 2818385  2018     12            31           2      19     7    2584.0
# 2818386  2018     12            31           7      19    16    2521.0
# 2818387  2018     12            31           3      10     0    1747.0
#
#          Total_Delay  DELAY_LEVEL  temp_x  pressure_x  wc_x  wspd_x  dewPt_x  \
# ...

# %%
tab_info=pd.DataFrame(final_merged_df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(final_merged_df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info
# Out:
#                    YEAR  MONTH DAY_OF_MONTH OP_CARRIER ORIGIN   DEST DISTANCE  \
# column type       int64  int64        int64      int64  int64  int64  float64
# null values (nb)      0      0            0          0      0      0        0
#
#                  Total_Delay DELAY_LEVEL   temp_x pressure_x     wc_x  \
# column type          float64       int64  float64    float64  float64
# null values (nb)           0           0        0          0        0
#
#                    wspd_x  dewPt_x    vis_x   temp_y pressure_y     wc_y  \
# column type       float64  float64  float64  float64    float64  float64
# null values (nb)        0        0        0        0          0        0
#
#                    wspd_y  dewPt_y    vis_y crs_dep_hour crs_dep_minute  \
# column type       float64  float64  float64        int64          int64
# null values (nb)        0        0        0            0              0
#
#                  crs_arr_hour crs_arr_minute
# ...

# %%
train, test = model_selection.train_test_split(final_merged_df, test_size=0.2, random_state = 42)

# %%
train_x = np.array(train.drop(['Total_Delay'], axis=1))
x_label = np.array(train['Total_Delay'])
test_y = np.array(test.drop(['Total_Delay'], axis = 1))
y_label = np.array(test['Total_Delay'])

# %%
print(train_x.shape, x_label.shape)
# Out:
# (2254710, 24) (2254710,)

# %%
lr = linear_model.LinearRegression()
model = lr.fit(train_x, x_label)

# %%
y_pred = model.predict(test_y)

# %%
y_pred
# Out:
# array([ -7.78646748, 163.13503423,  78.40209177, ...,  -2.7057299 ,
#         -4.08202545,  -5.64147424])

# %%
rmse_1 = metrics.mean_absolute_error(y_label, y_pred)
rmse_1
# Out:
# 23.47314723095685

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor(n_estimators=200, criterion='mse', max_features='sqrt', n_jobs=50, random_state=50)
rdr_model = rdr.fit(train_x, x_label)

# %%
y_pred = rdr_model.predict(test_y)

# %%
rmse_1 = metrics.mean_absolute_error(y_label, y_pred)
rmse_1

# %%
test.OP_CARRIER.unique()
# Out:
# array([ 1, 12,  4,  2, 11,  6, 15,  9,  3, 13,  8, 14, 10,  0,  5,  7])

# %%
temp1 = pd.DataFrame({"Value":y_label,"Type":"Actual"})
temp2 = pd.DataFrame({"Value":y_pred,"Actual":y_label, "Airline":test.OP_CARRIER})

# %%
#temp1 = pd.DataFrame({"Value":y_label,"Type":"Actual"})
temp2 = pd.DataFrame({"Predicted":y_pred,"Actual":y_label, "Airline":test.OP_CARRIER})

# %%
temp2 = temp2.groupby("Airline").mean().reset_index()

# %%
temp2['Carrier'] = carrier
temp2
# Out:
#     Airline  Predicted     Actual                       Carrier
# 0         0  33.103833  25.358409         United Air Lines Inc.
# 1         1  28.667074  25.459534        Frontier Airlines Inc.
# 2         2  25.132680  22.008437        American Airlines Inc.
# 3         3  33.660486  35.092111              Spirit Air Lines
# 4         4  24.068265  20.203309          Alaska Airlines Inc.
# 5         5  26.848122  35.934694               JetBlue Airways
# 6         6  29.457589  29.077962          Delta Air Lines Inc.
# 7         7  21.855385  37.538462        Southwest Airlines Co.
# 8         8  27.790021  22.192308             Republic Airlines
# 9         9  27.430168  24.494145         Skywest Airlines Inc.
# 10       10  26.375484  19.615573                  PSA Airlines
# 11       11  25.415105  23.755829                  Endeavor Air
# 12       12  30.781851  28.204307                 Mesa Airlines
# 13       13  25.375195  19.306012  American Eagle Airlines Inc.
# ...

# %%
temp2.plot(x="Carrier", y=["Predicted","Actual"], kind="bar")
plt.ylabel("Mean Total Delay")
plt.title("Predicted vs Actual average total delay by carrer")
plt.show()

# %%
temp = pd.concat([temp1, temp2]).reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-419-0ba99baf4bd8> in <module>
# ----> 1 temp = pd.barplot([temp1, temp2]).reset_index()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'barplot'

# %%
sns.barplot(x="Airline",y="Predicted", data=temp2)
sns.barplot(x="Airline",y="Actual", data=temp2)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Actual'>

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.barplot('DEST','ARR_DELAY', data=y_pred, palette = 'flare').set_title('ARRIVAL DELAY BY AIRPORTS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-400-c2cb86fe5561> in <module>
#       1 sns.set(rc={'figure.figsize':(20,7)})
# ----> 2 sns.barplot('DEST','ARR_DELAY', data=y_pred, palette = 'flare').set_title('ARRIVAL DELAY BY AIRPORTS')
#       3 plt.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
plt.plot(temp.index, temp.pred)

# %%
sns.scatterplot(y=temp.pred,x=temp.index, data=temp)
# Out:
# <AxesSubplot:ylabel='pred'>

# %%
sns.scatterplot(y=temp.actual,x=temp.index, data=temp)
# Out:
# <AxesSubplot:ylabel='actual'>

# %%
test_y = test.drop(['Total_Delay'], axis = 1)
test_y.reset_index()
# Out:
#           index  YEAR  MONTH  DAY_OF_MONTH  OP_CARRIER  OP_CARRIER_FL_NUM  \
# 0        644619  2019      6            11           1               2744
# 1       1248854  2019     11             3           1               1576
# 2        945065  2019      8            21          12                991
# 3       1014248  2019      9             7           1               1094
# 4       1805585  2020      3            20          12                479
# ...         ...   ...    ...           ...         ...                ...
# 477976   690208  2019      6            22           4               2925
# 477977   549981  2019      5            19          12                433
# 477978  1882272  2020      5            16          13               2072
# 477979   956700  2019      8            24          12                639
# 477980  2353616  2020     12            18           6               2383
#
#         ORIGIN  DEST  DISTANCE  temp_x  pressure_x  wc_x  wspd_x  dewPt_x  \
# ...

# %%
plt.rcParams["figure.figsize"] = (20,3)
plt.plot(test_y.index, y_label, label = "Actual Total Delay")
plt.plot(test_y.index, y_pred, label = "Predicted Total Delay")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     158             try:
# --> 159                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     160             except OverflowError as err:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# The above exception was the direct cause of the following exception:
#
# OverflowError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ...

# %%
import xgboost as xg
xgb = xg.XGBRegressor(learning_rate=0.2, n_estimators = 10, random_state = 42)
model_xgb = xgb.fit(train_x, x_label)

# %%
y_pred = model_xgb.predict(test_y)
rmse_1 = metrics.mean_absolute_error(y_label, y_pred)
rmse_1
# Out:
# 31.50201447265656

# %%
sns.set(rc={'figure.figsize':(13,9)})
sns.heatmap(final_merged_df.corr(), vmin=-1, vmax=1, cmap='seismic');

# %%
df_eda['delayed'] = np.where(df_eda['Total_Delay'] > 5, 1, 0)

# %%
df_eda
# Out:
#          YEAR  MONTH  DAY_OF_MONTH OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  \
# 0        2019      1             1         UA   N889UA               2112
# 1        2019      1             1         F9   N328FR               2000
# 2        2019      1             1         AA   N990AU                337
# 3        2019      1             1         UA   N75854                680
# 4        2019      1             1         UA   N37474                250
# ...       ...    ...           ...        ...      ...                ...
# 2361787  2020     12            31         UA   N2136U               1796
# 2361788  2020     12            31         NK   N684NK               1971
# 2361789  2020     12            31         UA   N24715               2388
# 2361790  2020     12            31         AA   N508AY               1886
# 2361791  2020     12            31         NK   N680NK                970
#
#         ORIGIN DEST CRS_DEP_TIME CRS_ARR_TIME  DISTANCE  Total_Delay temp_x  \
# ...

# %%
delays_by_airline = df_eda.groupby('OP_CARRIER').sum()['delayed']
flights_by_airline = df_eda.groupby('OP_CARRIER').count()['TAIL_NUM']
percent_delay_airline = delays_by_airline/flights_by_airline

plt.barh(percent_delay_airline.index,percent_delay_airline.sort_values())
plt.xlim(0,1)
plt.title('Percent of Flights Delayed by Airline');

# %%
df_eda.groupby(['OP_CARRIER']).size().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='OP_CARRIER'>

# %%
#df_eda.groupby(['ORIGIN']).size().plot(kind = "bar")

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
#temp_1 = df_eda[["ORIGIN"]
#temp_1.groupby(["Count"]).size().reset_index()
#sns.barplot(y='Sales',x='Assortment',data=temp_1,order=['a','b','c'],palette='Set2', ax=ax1).set(title="Avg Sales per assortment")
sns.histplot(x="ORIGIN",data=df_eda, ax= ax1)
sns.histplot(x="DEST",data=df_eda, ax= ax2)
plt.show()

# %%
#_____________________________________________
# Function that define how delays are grouped
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['df_eda'] = final_merged_df['Total_Delay'].apply(delay_type)
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="OP_CARRIER", hue='DELAY_LEVEL', data=df)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[1].set_text('small delay (5 < t < 45 min)')
L.get_texts()[2].set_text('large delay (t > 45 min)')
plt.show()

# %%
sns.countplot(x='OP_CARRIER', y='Total_Delay', data=df_eda)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-250d24cfbd5c> in <module>
# ----> 1 sns.countplot(x='OP_CARRIER', y='Total_Delay', data=df_eda)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3591         y = x
#    3592     elif x is not None and y is not None:
# -> 3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
#    3595     plotter = _CountPlotter(
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
# Sum up sales by week
temp1 = (df.groupby(["OP_CARRIER","YEAR"]).sum().reset_index())
#labels = [abbr_companies[item.get_text()] for item in ax.get_xticklabels()]
# Plot results
sns.set(rc={'figure.figsize':(19,7)})
ax = sns.pointplot(x = "OP_CARRIER", y="Total_Delay", hue="YEAR", data=temp1)
ax.set(title='Yearly delay by carrrier')
#ax.set_xticklabels(labels, rotation=90, ha="right")
plt.xlabel("Week No")
plt.tight_layout()

# %%
temp2 = df.groupby(["OP_CARRIER","YEAR"]).size().reset_index().rename(columns={0: "TOTAL_FLIGHTS"})
sns.barplot(x="OP_CARRIER", y="TOTAL_FLIGHTS", hue="YEAR", data=temp2)
plt.tight_layout()

# %%
delays_by_weekday = df_eda.groupby('DAY_OF_WEEK').sum()['Total_Delay']
#total_flights_weekday = df_eda.groupby('DAY_OF_WEEK').count()['tail_num']
#percent_delay_weekday = delays_by_weekday/total_flights_weekday

# %%
plt.bar(percent_delay_weekday.index,percent_delay_weekday)
plt.title('Percent of Flights Delayed by Day of Week',fontsize=18)
plt.xticks(ticks=range(1,8),labels=['Mon','Tu','Wed','Th','Fri','Sat','Sun'])
plt.ylim(0,1);
# Out:
#          YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK    FL_DATE  \
# 0        2019        4     12             9            1 2019-12-09
# 1        2019        4     12             9            1 2019-12-09
# 2        2019        4     12             9            1 2019-12-09
# 3        2019        4     12             9            1 2019-12-09
# 4        2019        4     12             9            1 2019-12-09
# ...       ...      ...    ...           ...          ...        ...
# 2380817  2020        1      2             7            5 2020-02-07
# 2380818  2020        1      2             7            5 2020-02-07
# 2380819  2020        1      2             7            5 2020-02-07
# 2380820  2020        1      2             7            5 2020-02-07
# 2380821  2020        1      2             7            5 2020-02-07
#
#          OP_CARRIER_AIRLINE_ID OP_CARRIER  OP_CARRIER_FL_NUM  \
# 0                        19393         WN                335
# ...

# %%
final_merged_df[final_merged_df.Total_Delay > 20]
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  OP_CARRIER  OP_CARRIER_FL_NUM  ORIGIN  \
# 9        2019      2             1           9                597      14
# 11       2019      2             1           9                597      14
# 12       2019      2             1           4               1331      11
# 17       2019      2             1           4               1331      11
# 28       2019      2             1           6               1418      10
# ...       ...    ...           ...         ...                ...     ...
# 2380771  2020     12            31           1               1054      13
# 2380772  2020     12            31           9                186       4
# 2380774  2020     12            31           1               1739      13
# 2380785  2020     12            31           6               2380       0
# 2380815  2020     12            31           4                356      18
#
#          DEST  DISTANCE  Total_Delay  temp_x  pressure_x  wc_x  wspd_x  \
# ...

# %%
final_merged_df
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  OP_CARRIER  TAIL_NUM  OP_CARRIER_FL_NUM  \
# 0        2019      1             1          12      4719               2112
# 1        2019      1             1           6      1357               2000
# 2        2019      1             1           1      5635                337
# 3        2019      1             1          12      3452                680
# 4        2019      1             1          12      1678                250
# ...       ...    ...           ...         ...       ...                ...
# 2361787  2020     12            31          12       689               1796
# 2361788  2020     12            31           9      3063               1971
# 2361789  2020     12            31          12       868               2388
# 2361790  2020     12            31           1      2211               1886
# 2361791  2020     12            31           9      3051                970
#
# ...
